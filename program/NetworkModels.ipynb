# %% [markdown]
# # ネットワークモデル

# %% [markdown]
# ## ERのランダムネットワーク

# %%
# %matplotlib inline
import networkx as nx

n = 100 # ノード数
p = 0.05 # リンク接続確率

print('ER network')
ER = nx.erdos_renyi_graph(n, p)
print(nx.info(ER))
print('L=', nx.average_shortest_path_length(ER))
print('C=', nx.average_clustering(ER))
pos = nx.circular_layout(ER)
nx.draw(ER, pos)
# Out:
# ER network
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 239
# Average degree:   4.7800
# L= 3.097171717171717
# C= 0.04167604617604618

# %% [markdown]
# ## WSのスモールワールドネットワーク

# %%
n = 100 # ノード数
k = 4 # 次数
p = 0.1 # リンク張り替え確率

print('WS network')
WS = nx.watts_strogatz_graph(n, k, p)
print(nx.info(WS))
print('L=', nx.average_shortest_path_length(WS))
print('C=', nx.average_clustering(WS))
pos = nx.circular_layout(WS)
nx.draw(WS, pos)
# Out:
# WS network
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 200
# Average degree:   4.0000
# L= 4.893737373737374
# C= 0.3667619047619048

# %% [markdown]
# ## BAのスケールフリーネットワーク

# %%
n = 100 # ノード数
m = 2 # 新規ノード接続リンク数

print('BA network')
BA = nx.barabasi_albert_graph(n, m)
print(nx.info(BA))
print('L=', nx.average_shortest_path_length(BA))
print('C=', nx.average_clustering(BA))
pos = nx.circular_layout(BA)
nx.draw(BA, pos)
# Out:
# BA network
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 196
# Average degree:   3.9200
# L= 2.936969696969697
# C= 0.12543394118497744
