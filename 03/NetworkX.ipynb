# %% [markdown]
# # NetworkX入門

# %% [markdown]
# ## ネットワーク作成

# %%
# Jupyter上で画像表示のため必要
# %matplotlib inline
# NetworkXをインポート
import networkx as nx

# ネットワーク生成
G = nx.Graph([(1, 2), (2, 3), (3, 1)])
nx.draw(G, with_labels=True, node_size=600) # ラベルをTrueにして番号の可視化
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 3
# Number of edges: 3
# Average degree:   2.0000

# %%
# ノードの追加
G.add_node(4)
nx.draw(G, with_labels=True, node_size=600)

# %%
# リンクの追加
G.add_edge(1,4)
nx.draw(G, with_labels=True, node_size=600)

# %%
# 複数ノードの追加
n = [5, 6, 7]
G.add_nodes_from(n)

# 複数リンクの追加
e = [(5,6), (3,7), (4,6)]
G.add_edges_from(e)

nx.draw(G, with_labels=True, node_size=600)

# %%
# ノードの削除
G.remove_node(4)

# リンクの削除
G.remove_edge(1, 2)

nx.draw(G, with_labels=True, node_size=600)

# %%
# 複数ノードの削除
G.remove_nodes_from([5, 6])

# 複数リンクの削除
G.remove_edges_from([(1,3), (3,7)])

nx.draw(G, with_labels=True, node_size=600)
